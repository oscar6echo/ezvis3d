# %%
import warnings
warnings.filterwarnings("ignore", module="matplotlib")

import os, sys
import pandas as pd

# %%
df = pd.read_csv(os.path.join('ezvis3d', 'api', 'ezvis3d_option.tsv'), sep='\t')
df.to_json(os.path.join('ezvis3d', 'api', 'ezvis3d_option.json'), orient='records')
df = pd.read_json(os.path.join('ezvis3d', 'api', 'ezvis3d_option.json'), orient='records')

df = df[['Name', 'Type', 'Default', 'Description']]
df
# Out:
#                            Name                Type  \
# 0             animationInterval              number
# 1              animationPreload             boolean
# 2            animationAutoStart             boolean
# 3                     axisColor              string
# 4               backgroundColor    string or Object
# 5          backgroundColor.fill              string
# 6        backgroundColor.stroke              string
# 7   backgroundColor.strokeWidth              number
# 8                cameraPosition              Object
# 9     cameraPosition.horizontal              number
# 10      cameraPosition.vertical              number
# 11      cameraPosition.distance              number
# 12                    dataColor    string or object
# 13               dataColor.fill              string
# 14             dataColor.stroke              string
# 15        dataColor.strokeWidth              number
# 16                    gridColor              string
# 17                       height              string
# 18              keepAspectRatio             boolean
# 19        showAnimationControls             boolean
# 20                     showGrid             boolean
# 21              showPerspective             boolean
# 22                   showShadow             boolean
# 23                        style              string
# 24                      tooltip  boolean | function
# 25                     valueMax              number
# 26                     valueMin              number
# 27                verticalRatio              number
# 28                        width              string
# 29                    xBarWidth              number
# 30                      xCenter              string
# 31                         xMax              number
# 32                         xMin              number
# 33                        xStep              number
# 34                  xValueLabel            function
# 35                    yBarWidth              number
# 36                      yCenter              string
# 37                         yMax              number
# 38                         yMin              number
# 39                        yStep              number
# 40                  yValueLabel            function
# 41                         zMin              number
# 42                         zMax              number
# 43                        zStep              number
# 44                  zValueLabel            function
# 45                       xLabel              String
# 46                       yLabel              String
# 47                       zLabel              String
# 48                  filterLabel              String
# 49                  legendLabel              String
#
#                                               Default  \
# 0                                                1000
# 1                                               false
# 2                                               false
# 3                                           '#4D4D4D'
# 4     {fill: 'white', stroke: 'gray', strokeWidth: 1}
# 5                                             'white'
# 6                                              'gray'
# 7                                                   1
# 8     {horizontal: 1.0, vertical: 0.5, distance: 1.7}
# 9                                                 1.0
# 10                                                0.5
# 11                                                1.7
# 12  {fill: '#7DC1FF', stroke: '#3267D2', strokeWid...
# 13                                          '#7DC1FF'
# 14                                          '#3267D2'
# 15                                                  1
# 16                                          '#D3D3D3'
# 17                                            '400px'
# 18                                               true
# 19                                               true
# 20                                               true
# 21                                               true
# 22                                              false
# 23                                              'dot'
# 24                                              false
# 25                                               none
# 26                                               none
# 27                                                0.5
# 28                                            '400px'
# 29                                               none
# 30                                              '55%'
# 31                                               none
# 32                                               none
# 33                                               none
# 34                                               none
# 35                                               none
# 36                                              '45%'
# 37                                               none
# 38                                               none
# 39                                               none
# 40                                               none
# 41                                               none
# 42                                               none
# 43                                               none
# 44                                               none
# 45                                                  x
# 46                                                  y
# 47                                                  z
# 48                                               time
# 49                                              value
#
#                                           Description
# 0   The animation interval in milliseconds. This d...
# 1   If false, the animation frames are loaded as s...
# 2   If true, the animation starts playing automati...
# 3   The color of the axis lines and the text along...
# 4   The background color for the main area of the ...
# 5      The chart fill color, as an HTML color string.
# 6   The color of the chart border, as an HTML colo...
# 7                        The border width, in pixels.
# 8   Set the initial rotation and position of the c...
# 9   Parameter horizontal is a value in radians and...
# 10  Parameter vertical is a value in radians betwe...
# 11  Parameter distance is the (normalized) distanc...
# 12  When dataColor is a string, it will set the co...
# 13  The border color of the dots or bars. Applicab...
# 14  The fill color of the dots or bars. Applicable...
# 15  The line width of dots, bars and lines. Applic...
# 16                       The color of the grid lines.
# 17  The height of the graph in pixels or as a perc...
# 18  If keepAspectRatio is true, the x-axis and the...
# 19  If true, animation controls are created at the...
# 20  If true, grid lines are draw in the x-y surfac...
# 21  If true, the graph is drawn in perspective: po...
# 22                          Show shadow on the graph.
# 23  The style of the 3d graph. Available styles: b...
# 24  Show a tooltip showing the values of the hover...
# 25  The maximum value for the value-axis. Only ava...
# 26  The minimum value for the value-axis. Only ava...
# 27  A value between 0.1 and 1.0. This scales the v...
# 28  The width of the graph in pixels or as a perce...
# 29  The width of bars in x direction. By default, ...
# 30  The horizontal center position of the graph, a...
# 31                  The maximum value for the x-axis.
# 32                  The minimum value for the x-axis.
# 33              Step size for the grid on the x-axis.
# 34  A function for custom formatting of the labels...
# 35  The width of bars in y direction. By default, ...
# 36  The vertical center position of the graph, as ...
# 37                  The maximum value for the y-axis.
# 38                  The minimum value for the y-axis.
# 39              Step size for the grid on the y-axis.
# 40  A function for custom formatting of the labels...
# 41                  The minimum value for the z-axis.
# 42                  The maximum value for the z-axis.
# 43              Step size for the grid on the z-axis.
# 44  A function for custom formatting of the labels...
# 45                               Label on the X axis.
# 46                               Label on the Y axis.
# 47                               Label on the Z axis.
# 48                       Label for the filter column.
# 49                   Label for the style description.

# %%
df = pd.read_csv(os.path.join('ezvis3d', 'api', 'ezvis3d_method.tsv'), sep='\t')
df.to_json(os.path.join('ezvis3d', 'api', 'ezvis3d_method.json'), orient='records')
df = pd.read_json(os.path.join('ezvis3d', 'api', 'ezvis3d_method.json'), orient='records')

df = df[['Method', 'Return Type', 'Description']]
df
# Out:
#                     Method                                        Return Type  \
# 0         animationStart()                                               none
# 1          animationStop()                                               none
# 2      getCameraPosition()  An object with parameters horizontal, vertical...
# 3                 redraw()                                               none
# 4            setData(data)                                               none
# 5      setOptions(options)                                               none
# 6   setSize(width, height)                                               none
# 7  setCameraPosition (pos)    {horizontal: 1.0, vertical: 0.5, distance: 1.7}
#
#                                          Description
# 0  Start playing the animation. Only applicable w...
# 1  Stop playing the animation. Only applicable wh...
# 2  Returns an object with parameters horizontal, ...
# 3  Redraw the graph. Useful after the camera posi...
# 4                   Replace the data in the Graph3d.
# 5  Update options of Graph3d. The provided option...
# 6  Parameters width and height are strings, conta...
# 7  Set the rotation and position of the camera. P...

# %%
df = pd.read_csv(os.path.join('ezvis3d', 'api', 'ezvis3d_dataset.tsv'), sep='\t')
df.to_json(os.path.join('ezvis3d', 'api', 'ezvis3d_dataset.json'), orient='records')
df = pd.read_json(os.path.join('ezvis3d', 'api', 'ezvis3d_dataset.json'), orient='records')

df = df[['Name', 'Type', 'Required', 'Description']]
df
# Out:
#      Name    Type Required                                        Description
# 0       x  number      yes                            Location on the x-axis.
# 1       y  number      yes                            Location on the y-axis.
# 2       z  number      yes                            Location on the z-axis.
# 3   style  number       no  The data value, required for graph styles dot-...
# 4  filter       *       no  Filter values used for the animation. This col...
