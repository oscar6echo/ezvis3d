# %%
from __future__ import division

import os, sys
import numpy as np
import pandas as pd
import datetime as dt
import random as rd

from IPython.display import display
from math import sin, cos, pi, sqrt

import ezvis3d as v3d
# Out:
# <script>
# require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#     console.log("The following js libs loaded:");
#     console.log("https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js");
#     window.vis = jQuery.extend(true, {}, lib);
#     console.log('vis js lib accessible as vis');
#
# });
# </script>
# Open console to check js libs were loaded in page

# %% [markdown]
# ##Examples
# + reproduced from http://visjs.org/graph3d_examples.html
# + For each `plot()` call passing `save=True` will save the graph as a stand alone HTML doc under ./saved
# + To center the plot in the output cell area, pass argument `center=True` to `plot()`

# %% [markdown]
# ###Basis
# + http://visjs.org/examples/graph3d/01_basics.html

# %%
def z(x, y):
    return 50+ sin(x/50) * cos(y/50) * 50

x_min = 0
x_max = 314
x_num = 50

x_rng = np.linspace(x_min, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y)}
            for y in y_rng
            for x in x_rng]
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'surface'
g.showPerspective = True
g.showGrid = True
g.showShadow = False
g.keepAspectRatio = True
g.verticalRatio = 0.7
g.cameraPosition = {'horizontal' : 0.9,
                    'vertical': 0.4,
                    'distance': 1.5
                   }

g.plot(df_data, save=True)
# Out:
#         <div id="494d4377_1c66_4734_9ade_350fae533af6"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"surface","cameraPosition":{"distance":1.5,"horizontal":0.9,"vertical":0.4},"keepAspectRatio":true,"showPerspective":true,"verticalRatio":0.7,"height":"600px","width":"600px","showShadow":false,"showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"x\":0.0,\"y\":0.0,\"z\":50.0},{\"x\":6.4081632653,\"y\":0.0,\"z\":56.3906344423},{\"x\":12.8163265306,\"y\":0.0,\"z\":62.6764410653},{\"x\":19.2244897959,\"y\":0.0,\"z\":68.7543115772},{\"x\":25.6326530612,\"y\":0.0,\"z\":74.5245485352},{\"x\":32.0408163265,\"y\":0.0,\"z\":79.8925007177},{\"x\":38.4489795918,\"y\":0.0,\"z\":84.7701157214},{\"x\":44.8571428571,\"y\":0.0,\"z\":89.0773843156},{\"x\":51.2653061224,\"y\":0.0,\"z\":92.7436528623},{\"x\":57.6734693878,\"y\":0.0,\"z\":95.7087822719},{\"x\":64.0816326531,\"y\":0.0,\"z\":97.9241344862},{\"x\":70.4897959184,\"y\":0.0,\"z\":99.3533703054},{\"x\":76.8979591837,\"y\":0.0,\"z\":99.973045473},{\"x\":83.306122449,\"y\":0.0,\"z\":99.7729952395},{\"x\":89.7142857143,\"y\":0.0,\"z\":98.7565010993},{\"x\":96.1224489796,\"y\":0.0,\"z\":96.9402369624},{\"x\":102.5306122449,\"y\":0.0,\"z\":94.3539956468},{\"x\":108.9387755102,\"y\":0.0,\"z\":91.0402001764},{\"x\":115.3469387755,\"y\":0.0,\"z\":87.053207901},{\"x\":121.7551020408,\"y\":0.0,\"z\":82.4584188541},{\"x\":128.1632653061,\"y\":0.0,\"z\":77.3312029727},{\"x\":134.5714285714,\"y\":0.0,\"z\
"x\":102.5306122449,\"y\":6.4081632653,\"z\":93.9902185694},{\"x\":108.9387755102,\"y\":6.4081632653,\"z\":90.7036017739},{\"x\":115.3469387755,\"y\":6.4081632653,\"z\":86.7493095152},{\"x\":121.7551020408,\"y\":6.4081632653,\"z\":82.1922054368},{\"x\":128.1632653061,\"y\":6.4081632653,\"z\":77.1070413161},{\"x\":134.5714285714,\"y\":6.4081632653,\"z\":71.5772308845},{\"x\":140.9795918367,\"y\":6.4081632653,\"z\":65.693481563},{\"x\":147.38 ...

# %% [markdown]
# ###Filter
# + http://visjs.org/examples/graph3d/03_filter_data.html

# %%
def z(x, y):
    return 50+ sin(x/50) * cos(y/50) * 50

def f(x, y):
    v = z(x, y)
    return '67-100' if v>66 else ('0-33' if v<34 else '34-66')

x_min = 0
x_max = 314
x_num = 50

x_rng = np.linspace(x_min, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y), 'filter': f(x, y)}
            for y in y_rng
            for x in x_rng]
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'surface'
g.showPerspective = False
g.showGrid = True
g.showShadow = False
g.keepAspectRatio = True
g.verticalRatio = 0.7
g.filterLabel = 'values'
g.cameraPosition = {'horizontal' : 0.9,
                    'vertical': 0.4,
                    'distance': 1.5
                   }
g.animationInterval = 1500
g.animationPreload = True
g.animationAutoStart = True

g.plot(df_data)
# Out:
#         <div id="d097a4b8_9119_4f7d_be5a_52768b16769f"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"surface","filterLabel":"values","animationPreload":true,"cameraPosition":{"distance":1.5,"horizontal":0.9,"vertical":0.4},"keepAspectRatio":true,"showPerspective":false,"verticalRatio":0.7,"height":"600px","width":"600px","animationAutoStart":true,"showShadow":false,"animationInterval":1500,"showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"filter\":\"34-66\",\"x\":0.0,\"y\":0.0,\"z\":50.0},{\"filter\":\"34-66\",\"x\":6.4081632653,\"y\":0.0,\"z\":56.3906344423},{\"filter\":\"34-66\",\"x\":12.8163265306,\"y\":0.0,\"z\":62.6764410653},{\"filter\":\"67-100\",\"x\":19.2244897959,\"y\":0.0,\"z\":68.7543115772},{\"filter\":\"67-100\",\"x\":25.6326530612,\"y\":0.0,\"z\":74.5245485352},{\"filter\":\"67-100\",\"x\":32.0408163265,\"y\":0.0,\"z\":79.8925007177},{\"filter\":\"67-100\",\"x\":38.4489795918,\"y\":0.0,\"z\":84.7701157214},{\"filter\":\"67-100\",\"x\":44.8571428571,\"y\":0.0,\"z\":89.0773843156},{\"filter\":\"67-100\",\"x\":51.2653061224,\"y\":0.0,\"z\":92.7436528623},{\"filter\":\"67-100\",\"x\":57.6734693878,\"y\":0.0,\"z\":95.7087822719},{\"filter\":\"67-100\",\"x\":64.0816326531,\"y\":0.0,\"z\":97.9241344862},{\"filter\":\"67-100\",\"x\":70.4897959184,\"y\":0.0,\"z\":99.3533703054},{\"filter\":\"67-100\",\"x\":76.8979591837,\"y\":0.0,\"z\":99.973045473},{\"filter\":\"67-100\",\"x
33\",\"x\":294.7755102041,\"y\":0.0,\"z\":31.0981464317},{\"filter\":\"34-66\",\"x\":301.1836734694,\"y\":0.0,\"z\":37.1695616893},{\"filter\":\"34-66\",\"x\":307.5918367347,\"y\":0.0,\"z\":43.4514391289},{\"filter\":\"34-66\",\"x\":314.0,\"y\":0.0,\"z\":49.8407349103},{\"filter\":\"34-66\",\"x\":0.0,\"y\":6.4081632653,\"z\":50.0},{\"filter\":\"34-66\",\"x\":6.4081632653,\"y\":6.4081632653,\"z\":56.3382205326},{\"filter\":\"34-66\",\"x\":12.8163265306,\"y\":6.4081632653,\"z\":62.5724730098},{\"filter\":\"67-100\",\"x\":19.2244897959,\"y\":6.4081632653,\"z\":68.6004948003},{\"filter\":\"67-100\",\"x\":25.632653061 ...

# %% [markdown]
# ###Animate
# + http://visjs.org/examples/graph3d/04_animation.html

# %%
def z(x, y, t):
    return 50+ sin(x/50 + t/10) * cos(y/50 + t/10) * 50

x_min = 0
x_max = 314
x_num = 25
t_max = 31
x_rng = np.linspace(x_min, x_max, x_num)
y_rng = x_rng
t_rng = range(t_max)
li_data = [{'x': x, 'y': y, 'z': z(x, y, t), 'filter': t}
            for y in y_rng
            for x in x_rng
            for t in t_rng]
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'surface'
g.showPerspective = True
g.showGrid = True
g.showShadow = False
g.keepAspectRatio = True
g.verticalRatio = 0.7
g.filterLabel = 'time'
g.cameraPosition = {'horizontal' : 0.9,
                    'vertical': 0.4,
                    'distance': 1.7
                   }
g.showAnimationControls = True
g.animationInterval = 100
g.animationPreload = True
g.animationAutoStart = True

g.plot(df_data)
# Out:
#         <div id="ea35dc24_b1d8_4a8a_a4a5_1e50563fc901"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"surface","filterLabel":"time","animationPreload":true,"cameraPosition":{"distance":1.7,"horizontal":0.9,"vertical":0.4},"keepAspectRatio":true,"showPerspective":true,"verticalRatio":0.7,"height":"600px","width":"600px","animationAutoStart":true,"showShadow":false,"animationInterval":100,"showGrid":true,"showAnimationControls":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"filter\":0,\"x\":0.0,\"y\":0.0,\"z\":50.0},{\"filter\":1,\"x\":0.0,\"y\":0.0,\"z\":54.9667332699},{\"filter\":2,\"x\":0.0,\"y\":0.0,\"z\":59.7354585577},{\"filter\":3,\"x\":0.0,\"y\":0.0,\"z\":64.1160618349},{\"filter\":4,\"x\":0.0,\"y\":0.0,\"z\":67.9339022725},{\"filter\":5,\"x\":0.0,\"y\":0.0,\"z\":71.0367746202},{\"filter\":6,\"x\":0.0,\"y\":0.0,\"z\":73.3009771492},{\"filter\":7,\"x\":0.0,\"y\":0.0,\"z\":74.6362432497},{\"filter\":8,\"x\":0.0,\"y\":0.0,\"z\":74.989340076},{\"filter\":9,\"x\":0.0,\"y\":0.0,\"z\":74.346190772},{\"filter\":10,\"x\":0.0,\"y\":0.0,\"z\":72.7324356706},{\"filter\":11,\"x\":0.0,\"y\":0.0,\"z\":70.2124100955},{\"filter\":12,\"x\":0.0,\"
333333,\"y\":0.0,\"z\":36.5761096896},{\"filter\":20,\"x\":13.0833333333,\"y\":0.0,\"z\":33.9639539536},{\"filter\":21,\"x\":13.0833333333,\"y\":0.0,\"z\":32.248934459},{\"filter\":22,\"x\":13.0833333333,\"y\":0.0,\"z\":31.4994236209},{\"filter\":23,\"x\":13.0833333333,\"y\":0.0,\"z\":31.7453020713},{\"filter\":24,\"x\":13.0833333333,\"y\":0.0,\"z\":32.9767674123},{\"filter\":25,\"x\":13.0833333333,\"y\":0.0,\"z\":35.1447250067},{\"filter\":26,\"x\":13.0833333333,\"y\":0.0,\"z\":38.1627452268},{\"filter\":27,\"x\":13.0833333333,\"y\":0.0,\"z\":41.9105091302},{\"filter\":28,\"x\":13.0833333333,\"y\":0.0,\"z\":46.2386051968},{\"filter\":29,\"x\":13.0833333333,\"y\":0.0,\"z\":50.9744858947},{\"filter\":30,\"x\":13.0833333333,\"y\":0.0,\"z\":55.9293466053},{\"filter\":0,\"x\":26.1666666667,\"y\":0.0,\"z\":74.9885051322},{\"filter\":1,\"x\":26.1666666667,\"y\":0.0,\"z\":79.0414281457},{\"filter\":2,\"x\":26.1666666667,\"y\":0.0,\"z\":82.4346674864},{\"filter\":3,\"x\":26.1666666667,\"y\":0 ...

# %% [markdown]
# ###Line
# + http://visjs.org/examples/graph3d/05_line.html

# %%
t_num = 500
t_max = 4*2*pi
t_rng = np.linspace(0, t_max, t_num)
r = 1.0
li_data = [{'x': r*sin(t), 'y': r*cos(t), 'z': t/t_max}
            for t in t_rng]
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'line'
g.showPerspective = False
g.showGrid = True
g.keepAspectRatio = True
g.verticalRatio = 1.0
g.cameraPosition = {'horizontal' : 0.44,
                    'vertical': 0.4,
                    'distance': 1.7
                   }

g.plot(df_data)
# Out:
#         <div id="00e3e143_4b18_4267_a1d9_bd954f1e20f0"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"line","cameraPosition":{"distance":1.7,"horizontal":0.44,"vertical":0.4},"keepAspectRatio":true,"showPerspective":false,"verticalRatio":1.0,"height":"600px","width":"600px","showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"x\":0.0,\"y\":1.0,\"z\":0.0},{\"x\":0.0503449231,\"y\":0.9987318903,\"z\":0.002004008},{\"x\":0.1005621605,\"y\":0.9949307774,\"z\":0.004008016},{\"x\":0.1505243501,\"y\":0.9886063018,\"z\":0.006012024},{\"x\":0.200104777,\"y\":0.9797745038,\"z\":0.0080160321},{\"x\":0.2491776943,\"y\":0.9684577826,\"z\":0.0100200401},{\"x\":0.2976186422,\"y\":0.95468484,\"z\":0.0120240481},{\"x\":0.345304764,\"y\":0.9384906073,\"z\":0.0140280561},{\"x\":0.3921151172,\"y\":0.9199161564,\"z\":0.0160320641},{\"x\":0.4379309804,\"y\":0.8990085964,\"z\":0.0180360721},{\"x\":0.4826361545,\"y\":0.8758209533,\"z\":0.0200400802},{\"x\":0.5261172575,\"y\":0.8504120362,\"z\":0.0220440882},{\"x\":0.5682640117,\"y\":0.8228462876,\
.1062124248},{\"x\":0.409418907,\"y\":-0.9123465124,\"z\":0.1082164329},{\"x\":0.3629677039,\"y\":-0.9318017203,\"z\":0.1102204409},{\"x\":0.315595935,\"y\":-0.9488936747,\"z\":0.1122244489},{\"x\":0.2674237456,\"y\":-0.9635790265,\"z\":0.1142284569},{\"x\":0.218573311,\"y\":-0.9758205305,\"z\":0.1162324649},{\"x\":0.1691685265,\"y\":-0.9855871396,\"z\":0.1182364729},{\"x\":0.1193346934,\"y\":-0.9928540834,\"z\":0.120240481},{\"x\":0.0691982015,\"y\":-0.9976029315,\"z\":0.122244489},{\"x\":0.0188862077,\"y\":-0.9998216397,\"z\":0.124248497},{\"x\":-0.0314736857,\"y\":-0.9995045808,\"z\":0.126252505},{\"x\":-0.0817537549,\"y\":-0.9966525591,\"z\":0.128256513},{\"x\":-0.1318264787,\"y\":-0.9912728078,\"z\":0.130260521},{\"x\":-0.1815648615,\"y\":-0.9833789712,\"z\":0.1322645291},{\"x\":-0.2308427561,\"y\":-0.9729910698,\"z\ ...

# %% [markdown]
# ###Moving Dots
# + http://visjs.org/examples/graph3d/06_moving_dots.html

# %%
t_max = 2*pi
t_step = 75
t_rng = np.linspace(0, t_max, t_step)
nb_dot_pair = 1
li_data = []

for t in t_rng:
    tgroup = round(t, 2)
    li_data.append({'x': 0, 'y': 0, 'z': 0, 'style': t, 'filter': tgroup})
    for d in range(nb_dot_pair):
        t_dot = t + 2 * pi * d / nb_dot_pair
        li_data.append({'x': sin(t_dot), 'y': cos(t_dot), 'z': sin(t_dot),
                        'style': t, 'filter': tgroup})
        li_data.append({'x': sin(t_dot), 'y': -cos(t_dot), 'z': sin(t_dot+t_max/2),
                        'style': t, 'filter': tgroup})
    
df_data = pd.DataFrame(li_data)


g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'dot-color'
g.showPerspective = True
g.showGrid = True
g.keepAspectRatio = True
g.verticalRatio = 1.0
g.filterLabel = 'time'
g.legendLabel = 'color value'
g.cameraPosition = {'horizontal' : 2.7,
                    'vertical': 0,
                    'distance': 1.6
                   }
g.showAnimationControls = True
g.animationInterval = 70
g.animationPreload = True
g.animationAutoStart = True

g.plot(df_data)
# Out:
#         <div id="1e301b37_016e_444b_827e_bd709ade28bc"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"dot-color","filterLabel":"time","animationPreload":true,"legendLabel":"color value","cameraPosition":{"distance":1.6,"horizontal":2.7,"vertical":0},"keepAspectRatio":true,"showPerspective":true,"verticalRatio":1.0,"height":"600px","width":"600px","animationAutoStart":true,"animationInterval":70,"showGrid":true,"showAnimationControls":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"filter\":0.0,\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":0.0},{\"filter\":0.0,\"style\":0.0,\"x\":0.0,\"y\":1.0,\"z\":0.0},{\"filter\":0.0,\"style\":0.0,\"x\":0.0,\"y\":-1.0,\"z\":1.224646799e-16},{\"filter\":0.08,\"style\":0.0849079096,\"x\":0.0,\"y\":0.0,\"z\":0.0},{\"filter\":0.08,\"style\":0.0849079096,\"x\":0.0848059245,\"y\":0.9963974885,\"z\":0.0848059245},{\"filter\":0.08,\"style\":0.0849079096,\"x\":0.0848059245,\"y\":-0.9963974885,\"z\":-0.0848059245},{\"filter\":0.17,\"style\":0.1698158191,\"x\":0.0,\"y\":0.0,\"z\":0.0},{\"filter\
\"x\":0.0,\"y\":0.0,\"z\":0.0},{\"filter\":1.1,\"style\":1.1038028242,\"x\":0.8929258581,\"y\":0.4502037448,\"z\":0.8929258581},{\"filter\":1.1,\"style\":1.1038028242,\"x\":0.8929258581,\"y\":-0.4502037448,\"z\":-0.8929258581},{\"filter\":1.19,\"style\":1.1887107338,\"x\":0.0,\"y\":0.0,\"z\":0.0},{\"filter\":1.19,\"style\":1.1887107338,\"x\":0.9278890273,\"y\":0.3728564778,\"z\":0.9278890273},{\"filter\":1.19,\"style\":1.1887107338,\"x\":0.9278890273,\"y\":-0.3728564778,\"z\":-0.9278890273},{\"filter\":1.27,\"style\":1.2736 ...

# %% [markdown]
# ###Dot Cloud Color
# + http://visjs.org/examples/graph3d/07_dot_cloud_colors.html

# %%
d_max = 100
d_rng = range(d_max)
li_data = []
rd.seed(123456)

for d in d_rng:
    x, y, z = rd.random()**2, rd.random()**2, rd.random()**2
    dist = sqrt(pow(x, 2) + pow(y, 2) + pow(z, 2))
    li_data.append({'x': x, 'y': y, 'z': z, 'style': dist})
    
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'dot-color'
g.showPerspective = True
g.showGrid = True
g.keepAspectRatio = True
g.verticalRatio = 1.0
g.legendLabel = 'distance'
g.cameraPosition = {'horizontal' : -0.35,
                    'vertical': 0.22,
                    'distance': 1.8
                   }

g.plot(df_data)
# Out:
#         <div id="d1386e1e_986d_474e_b9eb_b7db62fbd383"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"dot-color","legendLabel":"distance","cameraPosition":{"distance":1.8,"horizontal":-0.35,"vertical":0.22},"keepAspectRatio":true,"showPerspective":true,"verticalRatio":1.0,"height":"600px","width":"600px","showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.9048839739,\"x\":0.6490350827,\"y\":0.6305297122,\"z\":0.0008658754},{\"style\":0.4417951265,\"x\":0.0305048522,\"y\":0.0000049723,\"z\":0.4407407263},{\"style\":0.0736063265,\"x\":0.0059365947,\"y\":0.0721048138,\"z\":0.0135478402},{\"style\":0.245750206,\"x\":0.0524525376,\"y\":0.2375759026,\"z\":0.034635034},{\"style\":0.8466763459,\"x\":0.0005891202,\"y\":0.8346167386,\"z\":0.1423916685},{\"style\":0.8518220164,\"x\":0.4182994809,\"y\":0.1368679175,\"z\":0.7293102667},{\"style\":0.6500514955,\"x\":0.5879609901,\"y\":0.1937743715,\"z\":0.1982935045},{\"style\":0.8100348716,\"x\":0.717306396,\"y\":0.2539281778,\"z\":0.2777562024},{\"style\":0.8910355536,\"x\":0.6415456889,\"y\":0.001891804,\"z\":0.6183525757},{\"style\":0.2534949825,\"x\":0.0093539761,\"y\":0.2532014442,\"z\":0.007825468},{\"style\":0.9856931667,\"x\":0.6778614329,\"y\":0.6330061646,\"z\":0.3337635275},{\"style\":0.6336461775,\"x\":0.1958974779,\"y\":0.5930701134,\"z\":0.106768427},{\"style\":0.1496412955,\"x\":0.1363954295,\"y\":0.0603403061,\"z\":0.0121594238},{\"style\":0.7569556872,\"x\":0.7499276555,\"y\":0.0744712907,\"z\":0.0710242974},{\"style\
# %% [markdown]
# ###Dot Cloud Size
# + http://visjs.org/examples/graph3d/08_dot_cloud_size.html

# %%
d_max = 100
d_rng = range(d_max)
li_data = []
rd.seed(123456)

for d in d_rng:
    x, y, z = rd.random()**2, rd.random()**2, rd.random()**2
    dist = sqrt(pow(x, 2) + pow(y, 2) + pow(z, 2))
    li_data.append({'x': x, 'y': y, 'z': z, 'style': sqrt(2)-dist})
    
df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'dot-size'
g.showPerspective = False
g.showGrid = True
g.keepAspectRatio = True
g.verticalRatio = 1.0
g.legendLabel = 'value'
g.cameraPosition = {'horizontal' : -0.54,
                    'vertical': 0.5,
                    'distance': 1.6
                   }

g.plot(df_data)
# Out:
#         <div id="a9c18545_1511_4a77_803f_10750d186743"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"dot-size","legendLabel":"value","cameraPosition":{"distance":1.6,"horizontal":-0.54,"vertical":0.5},"keepAspectRatio":true,"showPerspective":false,"verticalRatio":1.0,"height":"600px","width":"600px","showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.5093295885,\"x\":0.6490350827,\"y\":0.6305297122,\"z\":0.0008658754},{\"style\":0.9724184358,\"x\":0.0305048522,\"y\":0.0000049723,\"z\":0.4407407263},{\"style\":1.3406072358,\"x\":0.0059365947,\"y\":0.0721048138,\"z\":0.0135478402},{\"style\":1.1684633563,\"x\":0.0524525376,\"y\":0.2375759026,\"z\":0.034635034},{\"style\":0.5675372165,\"x\":0.0005891202,\"y\":0.8346167386,\"z\":0.1423916685},{\"style\":0.5623915459,\"x\":0.4182994809,\"y\":0.1368679175,\"z\":0.7293102667},{\"style\":0.7641620668,\"x\":0.5879609901,\"y\":0.1937743715,\"z\":0.1982935045},{\"style\":0.6041786908,\"x\":0.717306396,\"y\":0.2539281778,\"z\":0.2777562024},{\"style\":0.5231780088,\"x\":0.6415456889,\"y\":0.001891804,\"z\":0.6183525757},{\"style\":1.1607185799,\"x\":0.0093539761,\"y\":0.2532014442,\"z\":0.007825468},{\"style\":0.4285203957,\"x\":0.6778614329,\"y\":0.6330061646,\"z\":0.3337635275},{\"style\":0.7805673849,\"x\":0.1958974779,\"y\":0.5930701134,\"z\":0.106768427},{\"style\":1.2645722669,\"x\":0.1363954295,\"y\":0.0603403061,\"z\":0.0121594238},{\"style\":0.6572578752,\"x\":0.7499276555,\"y\":0.0744712907,\"z\":0.0710242974},{\"style\":0.4762543247,\"x\":0.012693059,\"y\":0.9172628592,\"z\":0.1955383979},{\"style\":0.5642017624,\"x\":0.1594867372,\"y\":0.8349155082,\"z\":0.0003675055},{\"style\":1.1207006561,\"x\":0.2329600528,\"y\":0.010583764,\"z\":0.1782341827},{\"style\":0.7727297994,\"x\":0.0274
# %% [markdown]
# ###Bar Chart
# + http://visjs.org/examples/graph3d/10_styling.html

# %%
def z(x, y):
    return -sin(x/pi) * cos(y/pi) * 10 + 10
                
x_max = 10
x_num = 6
x_rng = np.linspace(0, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y), 'style': y-x}
            for y in y_rng
            for x in x_rng]

df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'bar-color'
g.xBarWidth = 0.6
g.yBarWidth = 0.9
g.showPerspective = True
g.showGrid = True
g.keepAspectRatio = True

g.plot(df_data)
# Out:
#         <div id="af09c1ee_20de_432f_8344_3054fadc94cb"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"style":"bar-color","yBarWidth":0.9,"keepAspectRatio":true,"showPerspective":true,"height":"600px","width":"600px","xBarWidth":0.6,"showGrid":true};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('af09c1ee_20de_432f_8344_3054fadc94cb');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>

# %% [markdown]
# ###Tooltips
# + http://visjs.org/examples/graph3d/11_tooltips.html

# %%
def z(x, y):
    return -sin(x/pi) * cos(y/pi) * 10 + 10
                
x_max = 10
x_num = 6
x_rng = np.linspace(0, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y), 'style': y-x}
            for y in y_rng
            for x in x_rng]

df_data = pd.DataFrame(li_data)

g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'bar-color'
g.showPerspective = True
g.showGrid = True
g.tooltip ="""
function (point) {
    // parameter point contains properties x, y, z
    return 'value: <b>' + parseFloat(point.z.toFixed(3)) + '</b>';
}
"""

g.plot(df_data)
# Out:
#         <div id="17f6d5ce_11be_4398_b174_ab787e0e442d"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"600px","style":"bar-color","showGrid":true,"showPerspective":true,"tooltip":"function (point) {\n    \/\/ parameter point contains properties x, y, z\n    return 'value: <b>' + parseFloat(point.z.toFixed(3)) + '<\/b>';\n}\n","height":"600px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('17f6d5ce_11be_4398_b174_ab787e0e442d');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>

# %% [markdown]
# ###Custom Labels
# + http://visjs.org/examples/graph3d/12_custom_labels.html

# %%
def z(x, y):
    return -sin(x/pi) * cos(y/pi) * 10 + 10
                
x_max = 10
x_num = 6
x_rng = np.linspace(0, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y), 'style': y-x}
            for y in y_rng
            for x in x_rng]

df_data = pd.DataFrame(li_data)
    
g = v3d.Vis3d()
g.width = '600px'
g.height = '600px'
g.style = 'bar-color'
g.showPerspective = True
g.showGrid = True
g.tooltip ="""
function (point) { return 'value: <b>' + parseFloat(point.z.toFixed(2)) + '</b>'; }
"""
g.xLabel = 'Date'
g.yLabel = 'Percentage'
g.zLabel = 'Temperature'

g.xValueLabel ="""
function(value) { return vis.moment().add(value, 'days').format('DD MMM'); }
"""
g.yValueLabel ="""
function(value) { return value * 10 + '%'; }
"""
g.zValueLabel ="""
function(value) { return value / 1000 + 'K'; }
"""

g.plot(df_data)
# Out:
#         <div id="aace18e7_e4f5_4402_8214_7ae1d092b9cc"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('aace18e7_e4f5_4402_8214_7ae1d092b9cc');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>

# %% [markdown]
# ###Styles
# + http://visjs.org/examples/graph3d/10_styling.html

# %%
def z(x, y):
    return -sin(x/pi) * cos(y/pi) * 10 + 10
                
x_max = 10
x_num = 6
x_rng = np.linspace(0, x_max, x_num)
y_rng = x_rng
li_data = [{'x': x, 'y': y, 'z': z(x, y), 'style': y-x}
            for y in y_rng
            for x in x_rng]

df_data = pd.DataFrame(li_data)
    
g = v3d.Vis3d()
g.width = '400px'
g.height = '400px'
g.showPerspective = True
g.showGrid = True


for s in ['bar', 'bar-color', 'bar-size', 'dot', 'dot-line',
          'dot-color', 'dot-size', 'line', 'grid', 'surface']:
    g.style = s
    display(g.plot(df_data, center=True))
# Out:
#         <div id="562b9615_84fe_441b_aed6_310209614b04" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"bar","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('562b9615_84fe_441b_aed6_310209614b04');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="40748ccf_67ab_4bbd_ae97_498e7311aff5" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"bar-color","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('40748ccf_67ab_4bbd_ae97_498e7311aff5');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="eda51173_3f44_452e_851e_04504e2e9c2b" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"bar-size","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('eda51173_3f44_452e_851e_04504e2e9c2b');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="1b27482b_6e09_4f13_a7a0_60c7cce05ca7" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"dot","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('1b27482b_6e09_4f13_a7a0_60c7cce05ca7');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="cb708251_99fe_4ca2_a861_2090d3020a07" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"dot-line","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('cb708251_99fe_4ca2_a861_2090d3020a07');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="e3db6216_7533_4832_b27d_f6d56f21a10b" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"dot-color","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('e3db6216_7533_4832_b27d_f6d56f21a10b');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="6058b7bc_4799_471a_ab07_dcf8b22e7131" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"dot-size","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('6058b7bc_4799_471a_ab07_dcf8b22e7131');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="4853dfd2_056a_4b6b_b678_cf3fa0026248" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"line","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('4853dfd2_056a_4b6b_b678_cf3fa0026248');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="ce5b7caf_ae4b_43d4_9d97_34114c172cb4" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"grid","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('ce5b7caf_ae4b_43d4_9d97_34114c172cb4');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>
#         <div id="30bfc096_26aa_4521_aa6f_25e0d4864967" style="margin: auto; width: 400px;"></div>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.css" rel="stylesheet" type="text/css" />
#     <script>
#     require(["https://cdnjs.cloudflare.com/ajax/libs/vis/4.7.0/vis.js"], function(lib) {
#         window.vis = jQuery.extend(true, {}, lib);
#
#     var options = {"width":"400px","style":"surface","showGrid":true,"showPerspective":true,"height":"400px"};
#
# var options = JSON.stringify(options);
#
# var options = JSON.parse(options, function(key, value) {
#
#     if (value && (typeof value==="string")) {
#
#         if (value.substr(0,8) == "function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#
#
#         if (value.substr(0,9)=="(function") {
#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(', 1) + 1;
#             var endArgs = value.indexOf(')');
#
#             var func = new Function(value.substring(startArgs, endArgs),
#                                     value.substring(startBody, endBody));
#             return func();
#         }
#     }
#
#     return value;
# });
#
#     window.opt = jQuery.extend(true, {}, options);
#     console.log('vis3d options accessible as opt');
#
#     var data = "[{\"style\":0.0,\"x\":0.0,\"y\":0.0,\"z\":10.0},{\"style\":-2.0,\"x\":2.0,\"y\":0.0,\"z\":4.0551923148},{\"style\":-4.0,\"x\":4.0,\"y\":0.0,\"z\":0.4394434267},{\"style\":-6.0,\"x\":6.0,\"y\":0.0,\"z\":0.5693326774},{\"style\":-8.0,\"x\":8.0,\"y\":0.0,\"z\":4.3939720116},{\"style\":-10.0,\"x\":10.0,\"y\":0.0,\"z\":10.414942917},{\"style\":2.0,\"x\":0.0,\"y\":2.0,\"z\":10.0},{\"style\":0.0,\"x\":2.0,\"y\":2.0,\"z\":5.2197217134},{\"style\":-2.0,\"x\":4.0,\"y\":2.0,\"z\":2.3122624961},{\"style\":-4.0,\"x\":6.0,\"y\":2.0,\"z\":2.4167077192},{\"style\":-6.0,\"x\":8.0,\"y\":2.0,\"z\":5.4921377972},{\"style\":-8.0,\"x\":10.0,\"y\":2.0,\"z\":10.3336596777},{\"style\":4.0,\"x\":0.0,\"y\":4.0,\"z\":10.0},{\"style\":2.0,\"x\":2.0,\"y\":4.0,\"z\":8.2570701813},{\"style\":0.0,\"x\":4.0,\"y\":4.0,\"z\":7.1969860058},{\"style\":-2.0,\"x\":6.0,\"y\":4.0,\"z\":7.2350676159},{\"style\":-4.0,\"x\":8.0,\"y\":4.0,\"z\":8.3563953853},{\"style\":-6.0,\"x\":10.0,\"y\":4.0,\"z\":10.1216551353},{\"style\":6.0,\"x\":0.0,\"y\":6.0,\"z\":10.0},{\"style\":4.0,\"x\":2.0,\"y\":6.0,\"z\":11.9772642924},{\"style\":2.0,\"x\":4.0,\"y\":6.0,\"z\":13.1798753011},{\"style\":0.0,\"x\":6.0,\"y\":6.0,\"z\":13.1366736719},{\"style\":-2.0,\"x\":8.0,\"y\":6.0,\"z\":11.8645849539},{\"style\":-4.0,\"x\":10.0,\"y\":6.0,\"z\":9.8619885021},{\"style\":8.0,\"x\":0.0,\"y\":8.0,\"z\":10.0},{\"style\":6.0,\"x\":2.0,\"y\":8.0,\"z\":14.9228051198},{\"style\":4.0,\"x\":4.0,\"y\":8.0,\"z\":17.9169519585},{\"style\":2.0,\"x\":6.0,\"y\":8.0,\"z\":17.8093926392},{\"style\":0.0,\"x\":8.0,\"y\":8.0,\"z\":14.6422667888},{\"style\":-2.0,\"x\":10.0,\"y\":8.0,\"z\":9.6563920611},{\"style\":10.0,\"x\":0.0,\"y\":10.0,\"z\":10.0},{\"style\":8.0,\"x\":2.0,\"y\":10.0,\"z\":15.9396876661},{\"style\":6.0,\"x\":4.0,\"y\":10.0,\"z\":19.5523224578},{\"style\":4.0,\"x\":6.0,\"y\":10.0,\"z\":19.4225450754},{\"style\":2.0,\"x\":8.0,\"y\":10.0,\"z\":15.6011997463},{\"style\":0.0,\"x\":10.0,\"y\":10.0,\"z\":9.5854144563}]";
#
# var data = JSON.parse(data);
#
#     window.dta = jQuery.extend(true, [], data);
#     console.log('vis3d data accessible as dta');
#
#
#     var container = document.getElementById('30bfc096_26aa_4521_aa6f_25e0d4864967');
#     console.log(options);
#     console.log(data);
#     graph3d = new vis.Graph3d(container, data, options);
#
#     });
#     </script>

# %% [markdown]
# ##Direct access to vis.js Graphe3d documentation
# + Reference http://visjs.org/docs/graph3d/
# + Navigate the object property tree
# + An `info()` method gives the official help
# + The usual ? postfix gives access to the same info
# + WARNING: Once a property is set, the info method is not accessible any more

# %%
g = v3d.Vis3d()

g.cameraPosition.info()
g.cameraPosition.distance.info()
# Out:
# <h4> Documentation for 'cameraPosition' </h4><br><li>Type </li>Object<br><br><li>Default </li>{horizontal: 1.0, vertical: 0.5, distance: 1.7}<br><br><li>Description </li>Set the initial rotation and position of the camera. The object cameraPosition contains three parameters: horizontal, vertical, and distance. Parameter horizontal is a value in radians and can have any value (but normally in the range of 0 and 2*Pi). Parameter vertical is a value in radians between 0 and 0.5*Pi. Parameter distance is the (normalized) distance from the camera to the center of the graph, in the range of 0.71 to 5.0. A larger distance puts the graph further away, making it smaller. All parameters are optional.<br><br>
# <h4> Documentation for 'cameraPosition.distance' </h4><br><li>Type </li>number<br><br><li>Default </li>1.7<br><br><li>Description </li>Parameter distance is the (normalized) distance from the camera to the center of the graph, in the range of 0.71 to 5.0. A larger distance puts the graph further away, making it smaller. This parameter is optional.<br><br>

# %%
g = v3d.Vis3d()
g.backgroundColor.info()
# Out:
# <h4> Documentation for 'backgroundColor' </h4><br><li>Type </li>string or Object<br><br><li>Default </li>{fill: 'white', stroke: 'gray', strokeWidth: 1}<br><br><li>Description </li>The background color for the main area of the chart. Can be either a simple HTML color string, for example: 'red' or '#00cc00', or an object with the following properties.<br><br>

# %%
g = v3d.Vis3d()
g.cameraPosition?
